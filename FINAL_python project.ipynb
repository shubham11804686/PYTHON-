# %%
# Creating CSV file as Atm.txt

import pandas as pd
c_name=["A","B","C","D","E","F","G","H","I","J"]
c_pin=[1111,2222,3333,4444,5555,6666,7777,8888,9999,1234]
c_balance= [10000,20000,30000,40000,50000,60000,70000,80000,90000,11000]
dict={"name":c_name,"pin":c_pin,"balance":c_balance}
df = pd.DataFrame(dict) 
df.to_csv("Atm.txt")

# %%
from tkinter import *
root=Tk()
def new_winF():
    newwin = Toplevel(root)
    newwin.geometry('400x300')
    newwin.title('Deposit')
    newwin.configure(bg='black')
    label1=Label(newwin,text='Enter the amount to be deposited',width=30,font=('bold',14))
    label1.place(x=20,y=40)
    label2=Label(newwin,text='Amount ',width=15,font=('bold',12))
    label2.place(x=20,y=100)
    entry2=Entry(newwin)
    entry2.place(x=200,y=100)
    label2=Label(newwin,text='pin ',width=15,font=('bold',12))
    label2.place(x=20,y=160)
    entry2=Entry(newwin)
    entry2.place(x=200,y=160)
    Button(newwin,text='Submit',width=30,bg='maroon',fg='white').place(x=100,y=240)
    
def new_winF1(): 
    newwin = Toplevel(root)
    newwin.geometry('400x300')
    newwin.title('Debit')
    newwin.configure(bg='black')
    label1=Label(newwin,text='Enter the amount to be withdrawl',width=30,font=('bold',14))
    label1.place(x=20,y=40)
    label2=Label(newwin,text='Amount ',width=15,font=('bold',12))
    label2.place(x=20,y=100)
    entry2=Entry(newwin)
    entry2.place(x=200,y=100)
    label2=Label(newwin,text='pin ',width=15,font=('bold',12))
    label2.place(x=20,y=160)
    entry2=Entry(newwin)
    entry2.place(x=200,y=160)
    Button(newwin,text='Submit',width=30,bg='maroon',fg='white').place(x=100,y=240)
def new_winF2(): 
    newwin = Toplevel(root)
    newwin.geometry('400x300')
    newwin.title('Net banking ')
    newwin.configure(bg='black')
    label1=Label(newwin,text='Enter ten digit mobile number below',width=30,font=('bold',14))
    label1.place(x=20,y=40)
    label2=Label(newwin,text='Mobile number',width=15,font=('bold',12))
    label2.place(x=20,y=100)
    entry2=Entry(newwin)
    entry2.place(x=200,y=100)
    label2=Label(newwin,text='pin ',width=15,font=('bold',12))
    label2.place(x=20,y=160)
    entry2=Entry(newwin)
    entry2.place(x=200,y=160)
    Button(newwin,text='Submit',width=30,bg='maroon',fg='white').place(x=100,y=240)
def new_winF3():
    newwin = Toplevel(root)
    newwin.geometry('400x300')
    newwin.title('Account setting ')
    newwin.configure(bg='black')
    label1=Label(newwin,text='Enter new pin number',width=30,font=('bold',14))
    label1.place(x=20,y=40)
    label2=Label(newwin,text='Old pin',width=15,font=('bold',12))
    label2.place(x=20,y=100)
    entry2=Entry(newwin)
    entry2.place(x=200,y=100)
    label2=Label(newwin,text='New pin ',width=15,font=('bold',12))
    label2.place(x=20,y=160)
    entry2=Entry(newwin)
    entry2.place(x=200,y=160)
    Button(newwin,text='Submit',width=30,bg='maroon',fg='white').place(x=100,y=240)
def new_winF4(): 
    newwin = Toplevel(root)
    newwin.geometry('400x300')
    newwin.title('Money Transfer ')
    newwin.configure(bg='black')
    label1=Label(newwin,text='Enter the amount to be transfer',width=30,font=('bold',14))
    label1.place(x=20,y=40)
    label2=Label(newwin,text='Amount',width=15,font=('bold',12))
    label2.place(x=20,y=100)
    entry2=Entry(newwin)
    entry2.place(x=200,y=100)
    label2=Label(newwin,text='Receiver pin',width=15,font=('bold',12))
    label2.place(x=20,y=160)
    entry2=Entry(newwin)
    entry2.place(x=200,y=160)
    Button(newwin,text='Submit',width=30,bg='maroon',fg='white').place(x=100,y=240)
def new_winF5(): 
    newwin = Toplevel(root)
    newwin.geometry('400x300')
    newwin.title('Apply for loan')
    newwin.configure(bg='black')
    label1=Label(newwin,text='Enter the amount and pin for loan',width=30,font=('bold',14))
    label1.place(x=20,y=40)
    label2=Label(newwin,text='Amount',width=15,font=('bold',12))
    label2.place(x=20,y=100)
    entry2=Entry(newwin)
    entry2.place(x=200,y=100)
    label2=Label(newwin,text='pin',width=15,font=('bold',12))
    label2.place(x=20,y=160)
    entry2=Entry(newwin)
    entry2.place(x=200,y=160)
    Button(newwin,text='Submit',width=30,bg='maroon',fg='white').place(x=100,y=240)
def new_winF6(): 
    newwin = Toplevel(root)
    newwin.geometry('400x300')
    newwin.title('Balance enquiry ')
    newwin.configure(bg='black')
    label1=Label(newwin,text='Enter pin to fetch balance',width=30,font=('bold',14))
    label1.place(x=20,y=40)
    label2=Label(newwin,text='pin',width=15,font=('bold',12))
    label2.place(x=20,y=100)
    entry2=Entry(newwin)
    entry2.place(x=200,y=100)
    Button(newwin,text='Submit',width=30,bg='maroon',fg='white').place(x=100,y=240)
def new_winF7():
    newwin = Toplevel(root)
    newwin.geometry('400x300')
    newwin.title('Mini statement')
    newwin.configure(bg='black')
    label1=Label(newwin,text='Enter pin to fetch Mini statement',width=30,font=('bold',14))
    label1.place(x=20,y=40)
    label2=Label(newwin,text='pin',width=15,font=('bold',12))
    label2.place(x=20,y=100)
    entry2=Entry(newwin)
    entry2.place(x=200,y=100)
    Button(newwin,text='Submit',width=30,bg='maroon',fg='white').place(x=100,y=240) 
def new_winF8():
    f1.pack_forget()
    root.geometry('500x300')
    root.title('ATM')
    root.configure(bg='black')
    label1=Label(root,text="Welcome to ATM",width=30,font=('bold',20))
    label1.place(x=0,y=20)
    label2=Label
    Button(root,text='Deposit',width=30,bg='maroon',fg='white',command =new_winF).place(x=1,y=100)
    Button(root,text='Withdrawl',width=30,bg='maroon',fg='white',command =new_winF1).place(x=275,y=100)
    Button(root,text='Net banking',width=30,bg='maroon',fg='white',command =new_winF2).place(x=1,y=150)
    Button(root,text='Account setting',width=30,bg='maroon',fg='white',command =new_winF3).place(x=275,y=150)
    Button(root,text='Money transfer',width=30,bg='maroon',fg='white',command =new_winF4).place(x=1,y=200)
    Button(root,text='Apply for loan',width=30,bg='maroon',fg='white',command =new_winF5).place(x=275,y=200)
    Button(root,text='Balance Enquiry',width=30,bg='maroon',fg='white',command =new_winF6).place(x=1,y=250)
    Button(root,text='Mini statement',width=30,bg='maroon',fg='white',command =new_winF7).place(x=275,y=250) 
    
f1 = Frame(root)
root.geometry('500x300')
filename = PhotoImage(file="‪F:\Desktop\atm-bccl.jpg")
background_label = Label(root, image=filename)
background_label.place(x=0, y=0, relwidth=1, relheight=1)
l1 = Label(f1, text="Welcome to ATM",width=30,font=('bold',20))
l1.pack()
b1 = Button(f1, text="Insert Card", command=new_winF8,bg='blue')
b1.pack()
f1.pack()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-2-3a60c736d3fa> in <module>
#     141 f1 = Frame(root)
#     142 root.geometry('500x300')
# --> 143 filename = PhotoImage(file="‪F:\Desktop\atm-bccl.jpg")
#     144 background_label = Label(root, image=filename)
#     145 background_label.place(x=0, y=0, relwidth=1, relheight=1)
#
# F:\anaconda\lib\tkinter\__init__.py in __init__(self, name, cnf, master, **kw)
#    3543         Valid resource names: data, format, file, gamma, height, palette,
#    3544         width."""
# -> 3545         Image.__init__(self, 'photo', name, cnf, master, **kw)
#    3546     def blank(self):
#    3547         """Display a transparent image."""
#
# F:\anaconda\lib\tkinter\__init__.py in __init__(self, imgtype, name, cnf, master, **kw)
#    3499                 v = self._register(v)
#    3500             options = options + ('-'+k, v)
# ...
